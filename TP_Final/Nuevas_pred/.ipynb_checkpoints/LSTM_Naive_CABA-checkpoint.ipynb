# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import keras
import tensorflow as tf
from sklearn.preprocessing import MinMaxScaler #scaling de los datos entre 0 y 1
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import GridSearchCV
from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.metrics import make_scorer
plt.style.use('seaborn')
plt.style.use('matplotlibrc.py')
# Out:
# Using TensorFlow backend.

# %%
seed = 7
np.random.seed(seed)

# %%
def create_dataset(dataset, time_step=1):
    dataX, dataY = [], []
    for i in range(len(dataset)-time_step-1):
        a = dataset[i:(i+time_step), 0]
        dataX.append(a)
        dataY.append(dataset[i + time_step, 0])
    return np.array(dataX), np.array(dataY)

# %%
def graph_predictions(l,df_original,y_train_pr,y_test_pr):
    plt.plot(df_original) 
    months_tr = np.arange(l,len(y_train_pr)+l) #meses de training
    months_ts = np.arange(len(y_train_pr)+(2*l)+1,len(df_original)-1) #meses de testing
    plt.plot(months_tr,y_train_pr,label='train') #grafico de train results
    plt.plot(months_ts,y_test_pr,label='test') #grafico de test results
    plt.xlabel('Meses')
    plt.ylabel('Pasajeros')
    plt.legend()
    plt.show()

# %%
file_dir = 'Datos/RiesgoBariloche'
data = pd.read_csv(file_dir,sep=",",quotechar='"',na_values=[''])
data = data["incidenciaAcum14d"]
df = pd.DataFrame(data)
plt.xlabel('Dias')
plt.ylabel('Casos/100mil hab')
plt.title('San Carlos de Bariloche')
plt.plot(df)
df = df.to_numpy()
df1 = df[-20:-10]
df = df[:-20]
df_original = np.copy(df)
df = df.flatten()
scaler = MinMaxScaler(feature_range=(0, 1))

# %%
plt.plot(df)
plt.xlabel('Dias')
plt.ylabel('Casos/100mil hab')
plt.title('San Carlos de Bariloche')
plt.savefig('test.pdf')

# %%
total_size = df.shape[0]
train_size = int(0.8*total_size)
test_size = total_size - train_size
train_data = df[:-test_size]
test_data = df[-test_size:]

# %%
print('Data train size: ',train_size)
print('Data test size: ',test_size)
# Out:
# Data train size:  244
# Data test size:  62

# %%
tw = 3
train_data_scaled = scaler.fit_transform(train_data.reshape(-1, 1))
x_train, y_train = create_dataset(train_data_scaled, tw)
x_train = x_train.reshape(x_train.shape[0],1,x_train.shape[1])
test_data_scaled = scaler.transform(test_data.reshape(-1, 1))
x_test, y_test = create_dataset(test_data_scaled, tw)
x_test = x_test.reshape(x_test.shape[0],1,x_test.shape[1])

# %%
model = keras.Sequential()
model.add(keras.layers.LSTM(units=64,activation='relu',input_shape=(1,tw)))
model.add(keras.layers.Dense(units=1))
model.compile(optimizer='adam',loss=keras.losses.MSE,metrics=['mse']) 
model.summary()
history = model.fit(x_train, y_train,epochs=500,validation_data=(x_test,y_test),batch_size=16,verbose=2)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 64)                17408
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 17,473
# Trainable params: 17,473
# Non-trainable params: 0
# _________________________________________________________________
# Train on 240 samples, validate on 58 samples
# Epoch 1/500
#  - 1s - loss: 0.0732 - mse: 0.0732 - val_loss: 1.1768 - val_mse: 1.1768
# Epoch 2/500
#  - 0s - loss: 0.0603 - mse: 0.0603 - val_loss: 0.9942 - val_mse: 0.9942
# Epoch 3/500
#  - 0s - loss: 0.0487 - mse: 0.0487 - val_loss: 0.8106 - val_mse: 0.8106
# Epoch 4/500
#  - 0s - loss: 0.0388 - mse: 0.0388 - val_loss: 0.6291 - val_mse: 0.6291
# Epoch 5/500
#  - 0s - loss: 0.0307 - mse: 0.0307 - val_loss: 0.4599 - val_mse: 0.4599
# Epoch 6/500
#  - 0s - loss: 0.0243 - mse: 0.0243 - val_loss: 0.3068 - val_mse: 0.3068
# Epoch 7/500
#  - 0s - loss: 0.0188 - mse: 0.0188 - val_loss: 0.1904 - val_mse: 0.1904
# Epoch 8/500
#  - 0s - loss: 0.0144 - mse: 0.0144 - val_loss: 0.1041 - val_mse: 0.1041
# Epoch 9/500
#  - 0s - loss: 0.0100 - mse: 0.0100 - val_loss: 0.0600 - val_mse: 0.0600
# Epoch 10/500
#  - 0s - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0275 - val_mse: 0.0275
# Epoch 11/500
#  - 0s - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0117 - val_mse: 0.0117
# Epoch 12/500
#  - 0s - loss: 0.0033 - mse: 0.0033 - val_loss: 0.0084 - val_mse: 0.0084
# Epoch 13/500
#  - 0s - loss: 0.0026 - mse: 0.0026 - val_loss: 0.0107 - val_mse: 0.0107
# Epoch 14/500
#  - 0s - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0139 - val_mse: 0.0139
# Epoch 15/500
#  - 0s - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0175 - val_mse: 0.0175
# Epoch 16/500
#  - 0s - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0182 - val_mse: 0.0182
# Epoch 17/500
#  - 0s - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0186 - val_mse: 0.0186
# Epoch 18/500
#  - 0s - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0166 - val_mse: 0.0166
# Epoch 19/500
#  - 0s - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0193 - val_mse: 0.0193
# Epoch 20/500
#  - 0s - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0229 - val_mse: 0.0229
# Epoch 21/500
#  - 0s - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0163 - val_mse: 0.0163
# Epoch 22/500
#  - 0s - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0171 - val_mse: 0.0171
# Epoch 23/500
#  - 0s - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0154 - val_mse: 0.0154
# Epoch 24/500
#  - 0s - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0181 - val_mse: 0.0181
# Epoch 25/500
#  - 0s - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0180 - val_mse: 0.0180
# Epoch 26/500
#  - 0s - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0168 - val_mse: 0.0168
# Epoch 27/500
#  - 0s - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0143 - val_mse: 0.0143
# Epoch 28/500
#  - 0s - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0156 - val_mse: 0.0156
# Epoch 29/500
#  - 0s - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0170 - val_mse: 0.0170
# Epoch 30/500
#  - 0s - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0181 - val_mse: 0.0181
# Epoch 31/500
#  - 0s - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0148 - val_mse: 0.0148
# Epoch 32/500
#  - 0s - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0146 - val_mse: 0.0146
# Epoch 33/500
#  - 0s - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0153 - val_mse: 0.0153
# Epoch 34/500
#  - 0s - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0134 - val_mse: 0.0134
# Epoch 35/500
#  - 0s - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0139 - val_mse: 0.0139
# Epoch 36/500
#  - 0s - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0122 - val_mse: 0.0122
# Epoch 37/500
#  - 0s - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0144 - val_mse: 0.0144
# Epoch 38/500
#  - 0s - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0150 - val_mse: 0.0150
# Epoch 39/500
#  - 0s - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0137 - val_mse: 0.0137
# Epoch 40/500
#  - 0s - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0107 - val_mse: 0.0107
# Epoch 41/500

# %%
train_predict=model.predict(x_train)
test_predict=model.predict(x_test)

# %%
print('train mse squared:',mean_squared_error(y_train,train_predict))
print('test mse squared:',mean_squared_error(y_test,test_predict))

# %%
train_predict=scaler.inverse_transform(train_predict)
test_predict=scaler.inverse_transform(test_predict)

# %%
plt.plot(history.history['loss'],label='train')
plt.plot(history.history['val_loss'],label='test')
plt.xlabel('Épocas')
plt.ylabel('Loss')
plt.legend(fontsize=12)

# %%
plt.plot(scaler.inverse_transform(y_train.reshape(-1,1)),label='train')
plt.plot(train_predict,label='train predict')
plt.legend(fontsize=12)
plt.xlabel('Dias')
plt.ylabel('Casos/100mil hab')

# %%
plt.plot(scaler.inverse_transform(y_test.reshape(-1,1)),label='test')
plt.plot(test_predict,label='test predict')
plt.xlabel('Dias')
plt.ylabel('Casos/100mil hab')
plt.legend(fontsize=12)

# %%
print('train mse squared:',mean_squared_error(scaler.inverse_transform(y_train.reshape(-1,1)),train_predict))
print('test mse squared:',mean_squared_error(scaler.inverse_transform(y_test.reshape(-1,1)),test_predict))

# %%
print(x_train.shape)

# %%
n = len(test_data_scaled)
lag = tw
x_input=test_data_scaled[n-lag:].reshape(1,-1)
temp_input=list(x_input)
temp_input=temp_input[0].tolist()
lst_output=[]
n_steps=lag
i=0

while(i<10): 
    if(len(temp_input)>lag):
        #print(temp_input)
        x_input=np.array(temp_input[1:])
        x_input=x_input.reshape(1,-1)
        x_input = x_input.reshape((1, 1, lag))
        #print(x_input)
        yhat = model.predict(x_input, verbose=0)
        print("{} day output {}".format(i,yhat))
        temp_input.extend(yhat[0].tolist())
        temp_input=temp_input[1:]
        #print(temp_input)
        lst_output.extend(yhat.tolist())
        i=i+1
    else:
        x_input = x_input.reshape((1, 1, lag))
        yhat = model.predict(x_input, verbose=0)
        temp_input.extend(yhat[0].tolist())
        lst_output.extend(yhat.tolist())
        i=i+1

# %%
lst_output = scaler.inverse_transform(lst_output)

# %%
plt.plot(lst_output,'o',label='forecast')
plt.plot(df1,label='true data')
plt.xlabel('Dias')
plt.ylabel('Casos/100mil hab')
plt.legend(fontsize=12)

# %%
graph_predictions(tw,df_original,train_predict,test_predict)
