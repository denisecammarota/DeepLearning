# %%
import time
import numpy as np
import matplotlib.pyplot as plt
from keras.datasets import cifar10
#using tensorfow backend
# Out:
# Using TensorFlow backend.

# %%
epocas = 300
e = range(300)
ts1,acc1 = np.genfromtxt('n_2_nprime_3.txt',delimiter=',')
ts2,acc2 = np.genfromtxt('n_2_nprime_4.txt',delimiter=',')
ts3,acc3 = np.genfromtxt('n_2_nprime_5.txt',delimiter=',')
ts4,acc4 = np.genfromtxt('n_2_nprime_7.txt',delimiter=',')
ts5,acc5 = np.genfromtxt('n_2_nprime_10.txt',delimiter=',')
plt.plot(e,acc1)
plt.plot(e,acc2)
plt.plot(e,acc3)
plt.plot(e,acc4)
plt.plot(e,acc5,c='k')

# %%
fig = plt.figure()
gs = fig.add_gridspec(2, 2, hspace=0, wspace=0)
(ax1, ax2), (ax3, ax4) = gs.subplots(sharex='col', sharey='row')
ax1.plot(e, acc1,label="n = 2, n' = 3")
ax1.plot(e,acc2,label="n = 2, n' = 4")
ax2.plot(e, acc3,label="n =2, n' = 5",c='r')
ax3.plot(e, acc4,label="n = 2, n' = 7",c='g')
ax4.plot(e, acc5,label="n = 2, n' = 10",c='k')
ax1.legend()
ax2.legend(loc=4)
ax3.legend()
ax4.legend()
ax1.set_ylim(-0.1,1.1)
ax3.set_ylim(-0.1,1.1)
fig.text(0.5, 0.02, 'Épocas', ha='center')
fig.text(0.02, 0.5, 'Accuracy', va='center', rotation='vertical')
plt.savefig('nnprime_2.pdf')
