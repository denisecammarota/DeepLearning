# %%
import keras 
import tensorflow as tf
from keras.datasets import cifar10
import numpy as np
from keras.callbacks import History 
import matplotlib.pyplot as plt
# Out:
# Using TensorFlow backend.

# %%
#ok funciona bien
#funcion que hace reshape de las imagenes
#sin agregar el bias
def reshapeImages(x,y):
    im_shape = x.shape[1:]
    x = np.reshape(x,(x.shape[0],np.prod(im_shape)))
    return x,y

# %% [markdown]
# # ejercicio 3 practica 2

# %%
#definicion de constantes
n_clases = 10 #cantidad de clases
n_capa1 = 100 #cantidad de neuronas capa 1
n_capa2 = n_clases #cantidad de neuronas capa 2 (= cantidad de clases)
#importamos los datos de training y testing
(x_train,y_train),(x_test,y_test) = cifar10.load_data() 
#reshaping y flatten
x_train,y_train = reshapeImages(x_train,y_train)
x_test,y_test = reshapeImages(x_test,y_test)
y_train = y_train.flatten()
y_test = y_test.flatten()
#pasamos al formato del ejercicio, creo los arrays
yy_train = np.zeros([x_train.shape[0],n_clases])
yy_test = np.zeros([x_test.shape[0],n_clases])
#pongo un 1 en la categoria correcta
yy_train[np.arange(x_train.shape[0]),y_train] = 1
yy_test[np.arange(x_test.shape[0]),y_test] = 1
#preprocesado de los datos
mean = np.mean(x_train,axis=0)
sigma = np.std(x_train,axis=0)
x_train = (x_train - mean)
x_test = (x_test - mean)
n_dim = x_train.shape[1] #dimension de entrada
epocas = 200 #cantidad de epocas

# %%
x = keras.layers.Input(shape=(n_dim,))
l1 = keras.layers.Dense(units=n_capa1, activation='sigmoid', use_bias=True, 
                           kernel_regularizer=keras.regularizers.l2(1e-3))(x)
l2 = keras.layers.Dense(units=n_capa2, activation='linear',use_bias=True,
                           kernel_regularizer=keras.regularizers.l2(1e-3))(l1)
model = keras.Model(inputs=x, outputs=l2)
optimizer = keras.optimizers.SGD(learning_rate=1e-2)
model.compile(optimizer, loss=keras.losses.MSE, metrics=['acc'])
history = model.fit(x_train, yy_train, epochs=epocas, validation_data=(x_test, yy_test),batch_size=100, verbose=2)
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/200
#  - 3s - loss: 0.4408 - acc: 0.1491 - val_loss: 0.3696 - val_acc: 0.1749
# Epoch 2/200
#  - 2s - loss: 0.3519 - acc: 0.1744 - val_loss: 0.3399 - val_acc: 0.1772
# Epoch 3/200
#  - 2s - loss: 0.3294 - acc: 0.1837 - val_loss: 0.3231 - val_acc: 0.1919
# Epoch 4/200
#  - 2s - loss: 0.3149 - acc: 0.1962 - val_loss: 0.3114 - val_acc: 0.1977
# Epoch 5/200
#  - 2s - loss: 0.3039 - acc: 0.2037 - val_loss: 0.3023 - val_acc: 0.2001
# Epoch 6/200
#  - 3s - loss: 0.2948 - acc: 0.2114 - val_loss: 0.2947 - val_acc: 0.2045
# Epoch 7/200
#  - 3s - loss: 0.2869 - acc: 0.2197 - val_loss: 0.2873 - val_acc: 0.2069
# Epoch 8/200
#  - 3s - loss: 0.2797 - acc: 0.2294 - val_loss: 0.2806 - val_acc: 0.2146
# Epoch 9/200
#  - 2s - loss: 0.2731 - acc: 0.2380 - val_loss: 0.2751 - val_acc: 0.2149
# Epoch 10/200
#  - 2s - loss: 0.2673 - acc: 0.2440 - val_loss: 0.2695 - val_acc: 0.2237
# Epoch 11/200
# Epoch 195/200
#  - 3s - loss: 0.0773 - acc: 0.5381 - val_loss: 0.0893 - val_acc: 0.3691
# Epoch 196/200
#  - 3s - loss: 0.0772 - acc: 0.5389 - val_loss: 0.0894 - val_acc: 0.3659
# Epoch 197/200
#  - 3s - loss: 0.0770 - acc: 0.5392 - val_loss: 0.0893 - val_acc: 0.3670
# Epoch 198/200
#  - 3s - loss: 0.0769 - acc: 0.5407 - val_loss: 0.0895 - val_acc: 0.3644
# Epoch 199/200
#  - 3s - loss: 0.0768 - acc: 0.5422 - val_loss: 0.0893 - val_acc: 0.3652
# Epoch 200/200
#  - 3s - loss: 0.0767 - acc: 0.5434 - val_loss: 0.0893 - val_acc: 0.3629

# %%
plt.plot(history.history['val_loss'],label='test data')
plt.plot(history.history['loss'],label='train data')
plt.legend()
plt.xlabel('Épocas')
plt.ylabel('Loss')
plt.savefig('ej2_1_loss.pdf')

# %%
plt.plot(history.history['val_acc'],label='test data')
plt.plot(history.history['acc'],label='train data')
plt.legend()
plt.xlabel('Épocas')
plt.ylabel('Accuracy')
plt.savefig('ej2_1_acc.pdf')

# %% [markdown]
# # ejercicio 4 practica 2

# %%
x = keras.layers.Input(shape=(n_dim,))
l1 = keras.layers.Dense(units=n_capa1, activation='sigmoid', use_bias=True, 
                           kernel_regularizer=keras.regularizers.l2(1e-3))(x)
l2 = keras.layers.Dense(units=n_capa2, activation='linear',use_bias=True,
                           kernel_regularizer=keras.regularizers.l2(1e-3))(l1)
model = keras.Model(inputs=x, outputs=l2)
optimizer = keras.optimizers.SGD(learning_rate=4e-3)
model.compile(optimizer, loss=keras.losses.categorical_crossentropy, metrics=['acc'])
history = model.fit(x_train, yy_train, epochs=epocas, validation_data=(x_test, yy_test),batch_size=100, verbose=2)
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/200
#  - 3s - loss: 6.8828 - acc: 0.1066 - val_loss: 6.3748 - val_acc: 0.1052
# Epoch 2/200
#  - 3s - loss: 6.2887 - acc: 0.1065 - val_loss: 6.2172 - val_acc: 0.1056
# Epoch 3/200
#  - 3s - loss: 6.1534 - acc: 0.1073 - val_loss: 6.0937 - val_acc: 0.1068
# Epoch 4/200
#  - 3s - loss: 6.0366 - acc: 0.1098 - val_loss: 5.9760 - val_acc: 0.1125
# Epoch 5/200
#  - 3s - loss: 5.9117 - acc: 0.1170 - val_loss: 5.9078 - val_acc: 0.1204
# Epoch 6/200
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-27-87edd5266558> in <module>
#       7 optimizer = keras.optimizers.SGD(learning_rate=4e-3)
#       8 model.compile(optimizer, loss=keras.losses.categorical_crossentropy, metrics=['acc'])
# ----> 9 history = model.fit(x_train, yy_train, epochs=epocas, validation_data=(x_test, yy_test),batch_size=100, verbose=2)
#
# ~\Anaconda3\envs\tf-gpu\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#    1237                                         steps_per_epoch=steps_per_epoch,
#    1238                                         validation_steps=validation_steps,
# -> 1239                                         validation_freq=validation_freq)
#    1240
#    1241     def evaluate(self,
#
# ~\Anaconda3\envs\tf-gpu\lib\site-packages\keras\engine\training_arrays.py in fit_loop(model, fit_function, fit_inputs, out_labels, batch_size, epochs, verbose, callbacks, val_function, val_inputs, shuffle, initial_epoch, steps_per_epoch, validation_steps, validation_freq)
#     184                             fit_inputs[:-1], batch_ids) + [fit_inputs[-1]]
#     185                     else:
# --> 186                         ins_batch = slice_arrays(fit_inputs, batch_ids)
#     187                 except TypeError:
#     188                     raise TypeError('TypeError while preparing batch. '
#
# ~\Anaconda3\envs\tf-gpu\lib\site-packages\keras\utils\generic_utils.py in slice_arrays(arrays, start, stop)
#     553             if hasattr(start, 'shape'):
#     554                 start = start.tolist()
# --> 555             return [None if x is None else x[start] for x in arrays]
#     556         else:
#     557             return [None if x is None else x[start:stop] for x in arrays]
#
# ~\Anaconda3\envs\tf-gpu\lib\site-packages\keras\utils\generic_utils.py in <listcomp>(.0)
#     553             if hasattr(start, 'shape'):
#     554                 start = start.tolist()
# --> 555             return [None if x is None else x[start] for x in arrays]
#     556         else:
#     557             return [None if x is None else x[start:stop] for x in arrays]
#
# KeyboardInterrupt:

# %%
plt.plot(history.history['val_loss'],label='test data')
plt.plot(history.history['loss'],label='train data')
plt.legend()
plt.xlabel('Épocas')
plt.ylabel('Loss')
plt.savefig('ej2_2_loss.pdf')

# %%
plt.plot(history.history['val_acc'],label='test data')
plt.plot(history.history['acc'],label='train data')
plt.legend()
plt.xlabel('Épocas')
plt.ylabel('Accuracy')
plt.savefig('ej2_2_acc.pdf')
